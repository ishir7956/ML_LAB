# %% [markdown]
# # Q1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
fig.show()
# Out:
# /tmp/ipykernel_4450/91020106.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Q2

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x, y)
ax2.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
fig1.show()
# Out:
# /tmp/ipykernel_4450/2085839923.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()

# %% [markdown]
# # Q3

# %%
df = pd.read_csv("/home/student/Desktop/company_sales_data.csv")
df.plot(x = 'month_number', y = 'total_profit')
plt.xlabel("month number")
plt.ylabel("total profit")
# Out:
# Text(0, 0.5, 'total profit')

# %% [markdown]
# # Q4

# %%
df = pd.read_csv("/home/student/Desktop/company_sales_data.csv")
total = df['total_profit'].sum()
df.plot(x = 'month_number', y = 'total_units', linestyle='dashed', marker = 'o', color='red', markerfacecolor = 'red', linewidth=3)
plt.xlabel("month number")
plt.ylabel("sold units number")
plt.legend(loc ="lower right")
plt.show()
total
# Out:
# 3123300

# %% [markdown]
# # ADDITIONAL QUESTIONS

# %% [markdown]
# # Q1

# %%
df = pd.read_csv("/home/student/Desktop/company_sales_data.csv")
df.plot(x = 'month_number', y = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer'])
plt.xlabel("month number")
plt.ylabel("sold units of each product")
plt.show()
